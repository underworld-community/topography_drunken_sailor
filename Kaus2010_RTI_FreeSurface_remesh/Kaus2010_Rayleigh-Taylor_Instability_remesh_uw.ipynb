# %% [markdown]
# Kaus2010_Rayleigh-Taylor_Instability
# ======
#
# <table><tr><td><img src='./pic/kaus2010_RT_image0000.png'></td></tr></table>
# Initial model setup with buoyancy perturbation.
#
# This notebook models the Rayleigh-Taylor instability outlined in van Kaus *et al.* (2010) for the FSSA algorithm test.
#
# The system of equations is given by
#
# $$
#     \nabla \cdot \left( \eta \nabla \dot\varepsilon \right) - \nabla p = -\rho g \mathbf{\hat z}
# $$
#
# $$
#     \nabla \cdot \mathbf{v} = 0
# $$
#
# **Keywords:** particle swarms, Stokes system, advective diffusive systems
#
# **References**
#
# - Kaus, B.J.P., et al., A stabilization algorithm for geodynamic numerical simulations with a free surface. Phys.
# Earth Planet. In. (2010), doi:10.1016/j.pepi.2010.04.007

# %%
import underworld as uw
from underworld import function as fn
import underworld.visualisation as vis

from underworld.scaling import units as u
from underworld.scaling import dimensionalise 
from underworld.scaling import non_dimensionalise as nd

import math
import numpy as np
import os

# %%
# build reference units
KL_meters   = 500 * u.kilometer
K_viscosity = 1e20  * u.pascal * u.second
K_density   = 3200 * u.kilogram / u.meter**3

# compute dependent scaling units 
#KT_seconds = 5*u.kiloyear
#KM_kilograms = KT_seconds * KL_meters * K_viscosity
KM_kilograms = K_density * KL_meters**3
KT_seconds   = KM_kilograms / ( KL_meters * K_viscosity )
K_substance  = 1. * u.mole
#Kt_degrees   = 1. * u.kelvin

scaling_coefficients = uw.scaling.get_coefficients()
scaling_coefficients["[length]"]      = KL_meters.to_base_units()
#scaling_coefficients["[temperature]"] = Kt_degrees.to_base_units()
scaling_coefficients["[time]"]        = KT_seconds.to_base_units()
scaling_coefficients["[mass]"]        = KM_kilograms.to_base_units()

gravity = nd( 9.81 * u.meter / u.second**2)

ymaxCoord = nd(0.* u.kilometer)
yminCoord = nd(-500* u.kilometer)
xmaxCoord = nd(250* u.kilometer)
xminCoord = nd(-250* u.kilometer)

# %%
useFSSA = False
useFreeSlip = False
useFreeSurface = True

time_step  = 1*u.kiloyear
#time_step  = 10*u.kiloyear

DT_str = "%.1f" %(time_step.m)
model_end_step  = 501 #int(nd(2e3*u.kiloyear)/nd(time_step)+1)
outputEvery = int(np.around(nd(1e2*u.kiloyear)/nd(time_step)))
stokes_inner_tol = 1e-6
stokes_outer_tol = 1e-5


# output path construction
output_path = "Kaus2010RTI_"
if useFreeSurface:
    output_path += "FreeSurface_"+DT_str+"ka_test_novo"
    
if useFreeSlip:
    output_path += "FreeSlip_"+DT_str+"ka"
    
if not output_path.endswith('/'): output_path += '/'

# search and build, if required, an output path
if uw.mpi.rank==0:
    try:
        if not os.path.exists("./"+output_path):
            os.makedirs("./"+output_path)
    except:
        raise
print(DT_str,model_end_step,outputEvery)

fn_dt = uw.function.misc.constant( nd(time_step) )
# Out:
# 1.0 501 100

# %%
# build mesh and mesh variables
resolution       = (64,64)
mesh = uw.mesh.FeMesh_Cartesian( elementType = 'Q1/dQ0', 
                                 elementRes  = resolution, 
                                 minCoord    = [xminCoord,yminCoord], 
                                 maxCoord    = [xmaxCoord,ymaxCoord],
                                 periodic    = [False, False] )

velocityField   = uw.mesh.MeshVariable( mesh=mesh,         nodeDofCount=mesh.dim )
pressureField   = uw.mesh.MeshVariable( mesh=mesh.subMesh, nodeDofCount=1 )

velocityField.data[:] = [0.,0.]
pressureField.data[:] = 0.

# %%
# Create a swarm.
swarm = uw.swarm.Swarm( mesh=mesh,particleEscape=True)
swarm2 = uw.swarm.Swarm( mesh=mesh, particleEscape=True)

# Create a data variable. It will be used to store the material index of each particle.
materialIndex = swarm.add_variable( dataType="int", count=1 )

# Create a layout object, populate the swarm with particles.
swarmLayout = uw.swarm.layouts.PerCellSpaceFillerLayout( swarm=swarm, particlesPerCell=20 )
swarm.populate_using_layout( layout=swarmLayout )
pop_control = uw.swarm.PopulationControl(swarm,aggressive=True,splitThreshold=0.15, maxDeletions=2,maxSplits=10,
                                                particlesPerCell=20)

# %%
# define these for convience. 
denseIndex = 0
lightIndex = 1

# material perturbation from van Keken et al. 1997
wavelength = nd(xmaxCoord*2)
amplitude  = nd(5*u.kilometer)
offset     = nd(-100.*u.kilometer)
k = 2. * math.pi / wavelength

# Create function to return particle's coordinate
coord = fn.coord()

# Define the material perturbation, a function of the x coordinate (accessed by `coord[0]`).
perturbationFn = offset + amplitude*fn.math.cos( k*coord[0] )

# Setup the conditions list. 
# If z is less than the perturbation, set to lightIndex.
conditions = [ ( perturbationFn > coord[1] , lightIndex ),
               (                      True , denseIndex ) ]

# The swarm is passed as an argument to the evaluation, providing evaluation on each particle.
# Results are written to the materialIndex swarm variable.
materialIndex.data[:] = fn.branching.conditional( conditions ).evaluate(swarm)


interfacePoints = np.zeros((resolution[0]*5,2))
interfacePoints[:,0] = np.linspace(xminCoord, xmaxCoord, resolution[0]*5)
for index in range(len(interfacePoints[:,0])):
    interfacePoints[index,1] = offset + amplitude*math.cos(k*interfacePoints[index,0])
tem = swarm2.add_particles_with_coordinates(interfacePoints)

# %%
fig1 = vis.Figure() #title="Material", figsize=(400,400), quality=2, rulers=True)
fig1.Points(swarm2,pointSize=5, colourBar=False)
fig1.Points(swarm, materialIndex, fn_size=2.,discret=True,colourBar = False) 
fig1.VectorArrows(mesh, velocityField) 
fig1.show()
fig1.save_image(output_path+"image_0")
# Out:
# <img src='data:image/png;base64,...'>
# 'Kaus2010RTI_FreeSurface_1.0ka_test_novo/image_0.png'

# %%
fig2 = vis.Figure() #title="Material", figsize=(400,400), quality=2, rulers=True)
#fig1.Points(swarm, materialIndex, fn_size=2.,discret=True,colourBar = False) 
#fig1.VectorArrows(mesh, velocityField) 
fig2.Mesh(mesh) 
fig2.show()
fig2.save_image(output_path+"mesh_0")
# Out:
# <img src='data:image/png;base64,...'>
# 'Kaus2010RTI_FreeSurface_1.0ka_test_novo/mesh_0.png'

# %%
light_density = nd(3200 * u.kilogram / u.meter**3)
dense_density = nd(3300 * u.kilogram / u.meter**3)
light_viscosity = nd(1e20 * u.pascal * u.second)
dense_viscosity = nd(1e21 * u.pascal * u.second)


# Set a density of '0.' for light material, '1.' for dense material.
densityMap   = { lightIndex:light_density, denseIndex:dense_density }
densityFn    = fn.branching.map( fn_key = materialIndex, mapping = densityMap )

# Set a viscosity value of '1.' for both materials.
viscosityMap = { lightIndex:light_viscosity, denseIndex:dense_viscosity }
fn_viscosity  = fn.branching.map( fn_key = materialIndex, mapping = viscosityMap )

# Define a vertical unit vector using a python tuple.
z_hat = ( 0.0, -1.0 )

# Create buoyancy force vector
buoyancyFn = densityFn*z_hat*gravity

# %%
# Construct node sets using the mesh specialSets
iWalls = mesh.specialSets["Left_VertexSet"]   + mesh.specialSets["Right_VertexSet"]
jWalls = mesh.specialSets["Bottom_VertexSet"] + mesh.specialSets["Top_VertexSet"]
botWalls = mesh.specialSets["Bottom_VertexSet"]
allWalls = iWalls + jWalls

if useFreeSurface:
    # free slip sides, no slip bottom, open top
    stokesBC = uw.conditions.DirichletCondition( variable      = velocityField, 
                                             indexSetsPerDof = (iWalls+botWalls, botWalls) )

# if useFreeSlip:
#     # free slip sides, no slip bottom, free lip top
#     stokesBC = uw.conditions.DirichletCondition( variable      = velocityField, 
#                                              indexSetsPerDof = (iWalls+botWalls,jWalls) )

# %%
# define an update function
fn_fssa = None
proj_buoy = True # for initial debug
if useFSSA == True:
    print("use FSSA")
    fn_fssa = buoyancyFn * DT *  theta
    
if proj_buoy == True:
    pbuoy = mesh.add_variable(nodeDofCount=mesh.dim)
    projB = uw.utils.MeshVariable_Projection(pbuoy, fn=buoyancyFn)

stokes = uw.systems.Stokes( velocityField = velocityField, 
                            pressureField = pressureField,
                            conditions    = stokesBC,
                            fn_viscosity  = fn_viscosity, 
                            fn_bodyforce  = buoyancyFn)#,
                           # _fn_fssa      = fn_fssa)
                           # _fn_fssa      = fn_fssa)

solver = uw.systems.Solver( stokes )

# Optional solver settings
if(uw.mpi.size==1):
    solver.set_inner_method("lu")
solver.set_inner_rtol(stokes_inner_tol) 
solver.set_outer_rtol(stokes_outer_tol) 

# Create a system to advect the swarm
advector = uw.systems.SwarmAdvector( swarm=swarm, velocityField=velocityField, order=2 )
advector2 = uw.systems.SwarmAdvector( swarm=swarm2, velocityField=velocityField, order=2 )

# %%
# projB.solve()
# fig = vis.Figure() #title="Material", figsize=(400,400), quality=2, rulers=True)
# # fig.Sur(swarm, materialIndex, fn_size=2.,discret=True,colourBar = False) 
# fig.append( vis.objects.Surface(mesh, buoyancyFn[1], colours="blue white red") )

# fig.VectorArrows(mesh, buoyancyFn) 
# fig.show()
# # fig1.save_image(output_path+"image_0")

# %%
from scipy.interpolate import interp1d
import underworld as uw
from mpi4py import MPI as _MPI

comm = _MPI.COMM_WORLD
rank = comm.rank
size = comm.size

class FreeSurfaceProcessor(object):
    """FreeSurfaceProcessor"""

    def __init__(self):
        """Create a Freesurface processor


        """
        # Create the tools
        self.TField = mesh.add_variable(nodeDofCount=1)
        self.TField.data[:, 0] = mesh.data[:, 1]

        self.top = mesh.specialSets["Top_VertexSet"]
        self.bottom = mesh.specialSets["Bottom_VertexSet"]

        # Create boundary condition
        self._conditions = uw.conditions.DirichletCondition(
            variable=self.TField,
            indexSetsPerDof=(self.top + self.bottom,))

        # Create Eq System
        self._system = uw.systems.SteadyStateHeat(
            temperatureField=self.TField,
            fn_diffusivity=1.0,
            conditions=self._conditions)

        self._solver = uw.systems.Solver(self._system)

    def _solve_sle(self):
        self._solver.solve()

    def _advect_surface(self, dt):

        if self.top:
            # Extract top surface
            x =  mesh.data[self.top.data][:, 0]
            y =  mesh.data[self.top.data][:, 1]

            # Extract velocities from top
            vx = velocityField.data[self.top.data][:, 0]
            vy = velocityField.data[self.top.data][:, 1]

            # Advect top surface
            x2 = x + vx * nd(dt)
            y2 = y + vy * nd(dt)

            # Spline top surface
            f = interp1d(x2, y2, kind='cubic', fill_value='extrapolate')

            self.TField.data[self.top.data, 0] = f(x)
        comm.Barrier()
        self.TField.syncronise()

    def _update_mesh(self):

        with  mesh.deform_mesh():
            # Last dimension is the vertical dimension
             mesh.data[:, -1] = self.TField.data[:, 0]

    def solve(self, dtime):
        """ Advect free surface through dt and update the mesh """

        # First we advect the surface
        self._advect_surface(dtime)
        # Then we solve the system of linear equation
        self._solve_sle()
        # Finally we update the mesh
        self._update_mesh()

# %%
# Initialise time and timestep.
time = 0.
step = 0

# parameters for output
timeVal     = []
vrmsVal     = []

# Save mesh and retain file handle for future xdmf creation
meshFileHandle = mesh.save(output_path+"Mesh.h5")


def update():   
    #dt = advector.get_max_dt() # retrieve the maximum possible timestep from the advection system.
    dt = fn_dt.value 
    advector.integrate(dt, update_owners=False)  #?update_owners=True
    advector2.integrate(dt,update_owners=False)
        
    #pop_control.repopulate()
    
    if useFreeSurface:
        freesuface =  FreeSurfaceProcessor()
        freesuface.solve(dt)

        
    swarm.update_particle_owners()
    swarm2.update_particle_owners()
    pop_control.repopulate()
    
    return time+dt, step+1, dt

# %%
while step < model_end_step:
    # Get solution
    solver.solve()
    
    # Calculate the RMS velocity.
    vrms = stokes.velocity_rms()

    # Record values into arrays
    if(uw.mpi.rank==0):
        vrmsVal.append(dimensionalise(vrms,u.meter/u.year).m)
        timeVal.append(dimensionalise(time, u.kiloyear).m)
     
    time, step, dt = update()
    if(uw.mpi.rank==0):
        string = "{:4d}, {:.3e},{:.3e},{:.3e}".format(step,dimensionalise(dt, u.kiloyear),dimensionalise(time, u.kiloyear),dimensionalise(vrms,u.meter/u.year)) 
        print(string)
                                                   
    # Output to disk
    if step%outputEvery == 0:
        #if(uw.mpi.rank==0):
        #    print('step = {0:6d}; time = {1:.3e}; v_rms = {2:.3e}'.format(step,time,vrms))

        filename = output_path+"/velocityField."+str(step).zfill(4)
        vFH      = velocityField.save(filename+".h5")
        velocityField.xdmf( filename, vFH, "velocity", meshFileHandle, "Mesh", time )
        
        filename = output_path+"/pressureField."+str(step).zfill(4)
        pFH      = pressureField.save(filename+".h5")
        pressureField.xdmf(filename, pFH, "pressure", meshFileHandle, "Mesh", time )
        
        swarm2.save(output_path+"surfaceSwarm"+ str(step).zfill(4)+".h5")
        
        outputFilename = output_path+"image"+str(step).zfill(4)
        fig1.save_image(outputFilename)

        outputFilename = output_path+"mesh"+str(step).zfill(4)
        fig2.save_image(outputFilename)

        
    # We are finished with current timestep, update.
    #updateMesh()

fname_save = output_path+"data_time_vrms.txt"
np.savetxt(fname_save, np.column_stack((timeVal ,vrmsVal)),fmt='%1.3e %1.3e')
# Out:
#    1, 1.000e+00 kiloyear,1.000e+00 kiloyear,7.627e-03 meter / year
#    2, 1.000e+00 kiloyear,2.000e+00 kiloyear,6.965e-03 meter / year
#    3, 1.000e+00 kiloyear,3.000e+00 kiloyear,6.338e-03 meter / year
#    4, 1.000e+00 kiloyear,4.000e+00 kiloyear,5.849e-03 meter / year
#    5, 1.000e+00 kiloyear,5.000e+00 kiloyear,5.226e-03 meter / year
#    6, 1.000e+00 kiloyear,6.000e+00 kiloyear,4.809e-03 meter / year
#    7, 1.000e+00 kiloyear,7.000e+00 kiloyear,4.427e-03 meter / year
#    8, 1.000e+00 kiloyear,8.000e+00 kiloyear,4.151e-03 meter / year
#    9, 1.000e+00 kiloyear,9.000e+00 kiloyear,3.836e-03 meter / year
#   10, 1.000e+00 kiloyear,1.000e+01 kiloyear,3.570e-03 meter / year
#   11, 1.000e+00 kiloyear,1.100e+01 kiloyear,3.273e-03 meter / year
#   12, 1.000e+00 kiloyear,1.200e+01 kiloyear,3.216e-03 meter / year
#   13, 1.000e+00 kiloyear,1.300e+01 kiloyear,3.293e-03 meter / year
#   14, 1.000e+00 kiloyear,1.400e+01 kiloyear,3.087e-03 meter / year
#   15, 1.000e+00 kiloyear,1.500e+01 kiloyear,2.713e-03 meter / year
#   16, 1.000e+00 kiloyear,1.600e+01 kiloyear,2.671e-03 meter / year
#   17, 1.000e+00 kiloyear,1.700e+01 kiloyear,2.595e-03 meter / year
#   18, 1.000e+00 kiloyear,1.800e+01 kiloyear,2.598e-03 meter / year
#   19, 1.000e+00 kiloyear,1.900e+01 kiloyear,2.516e-03 meter / year
#   20, 1.000e+00 kiloyear,2.000e+01 kiloyear,2.427e-03 meter / year
#   21, 1.000e+00 kiloyear,2.100e+01 kiloyear,2.195e-03 meter / year
#   22, 1.000e+00 kiloyear,2.200e+01 kiloyear,2.235e-03 meter / year
#   23, 1.000e+00 kiloyear,2.300e+01 kiloyear,2.170e-03 meter / year
#   24, 1.000e+00 kiloyear,2.400e+01 kiloyear,2.071e-03 meter / year
#   25, 1.000e+00 kiloyear,2.500e+01 kiloyear,2.106e-03 meter / year
#   26, 1.000e+00 kiloyear,2.600e+01 kiloyear,2.240e-03 meter / year
#   27, 1.000e+00 kiloyear,2.700e+01 kiloyear,2.315e-03 meter / year
#   28, 1.000e+00 kiloyear,2.800e+01 kiloyear,2.134e-03 meter / year
#   29, 1.000e+00 kiloyear,2.900e+01 kiloyear,2.174e-03 meter / year
#   30, 1.000e+00 kiloyear,3.000e+01 kiloyear,2.189e-03 meter / year
#  278, 1.000e+00 kiloyear,2.780e+02 kiloyear,2.601e-03 meter / year
#  279, 1.000e+00 kiloyear,2.790e+02 kiloyear,2.548e-03 meter / year
#  280, 1.000e+00 kiloyear,2.800e+02 kiloyear,2.582e-03 meter / year
#  281, 1.000e+00 kiloyear,2.810e+02 kiloyear,2.655e-03 meter / year
#  282, 1.000e+00 kiloyear,2.820e+02 kiloyear,2.641e-03 meter / year
#  283, 1.000e+00 kiloyear,2.830e+02 kiloyear,2.774e-03 meter / year
#  284, 1.000e+00 kiloyear,2.840e+02 kiloyear,2.643e-03 meter / year
#  285, 1.000e+00 kiloyear,2.850e+02 kiloyear,2.624e-03 meter / year
#  286, 1.000e+00 kiloyear,2.860e+02 kiloyear,2.609e-03 meter / year
#  287, 1.000e+00 kiloyear,2.870e+02 kiloyear,2.637e-03 meter / year
#  288, 1.000e+00 kiloyear,2.880e+02 kiloyear,2.603e-03 meter / year
#  289, 1.000e+00 kiloyear,2.890e+02 kiloyear,2.694e-03 meter / year
#  290, 1.000e+00 kiloyear,2.900e+02 kiloyear,2.534e-03 meter / year
#  291, 1.000e+00 kiloyear,2.910e+02 kiloyear,2.552e-03 meter / year
#  292, 1.000e+00 kiloyear,2.920e+02 kiloyear,2.593e-03 meter / year
#  293, 1.000e+00 kiloyear,2.930e+02 kiloyear,2.553e-03 meter / year
#  294, 1.000e+00 kiloyear,2.940e+02 kiloyear,2.641e-03 meter / year
#  295, 1.000e+00 kiloyear,2.950e+02 kiloyear,2.564e-03 meter / year
#  296, 1.000e+00 kiloyear,2.960e+02 kiloyear,2.578e-03 meter / year
#  297, 1.000e+00 kiloyear,2.970e+02 kiloyear,2.737e-03 meter / year
#  298, 1.000e+00 kiloyear,2.980e+02 kiloyear,2.532e-03 meter / year
#  299, 1.000e+00 kiloyear,2.990e+02 kiloyear,2.541e-03 meter / year
#  300, 1.000e+00 kiloyear,3.000e+02 kiloyear,2.636e-03 meter / year
#  301, 1.000e+00 kiloyear,3.010e+02 kiloyear,2.656e-03 meter / year
#  302, 1.000e+00 kiloyear,3.020e+02 kiloyear,2.632e-03 meter / year
#  303, 1.000e+00 kiloyear,3.030e+02 kiloyear,2.568e-03 meter / year
#  304, 1.000e+00 kiloyear,3.040e+02 kiloyear,2.618e-03 meter / year
#  305, 1.000e+00 kiloyear,3.050e+02 kiloyear,2.618e-03 meter / year
#  306, 1.000e+00 kiloyear,3.060e+02 kiloyear,2.760e-03 meter / year
#  307, 1.000e+00 kiloyear,3.070e+02 kiloyear,2.795e-03 meter / year
#  308, 1.000e+00 kiloyear,3.080e+02 kiloyear,2.823e-03 meter / year
#  309, 1.000e+00 kiloyear,3.090e+02 kiloyear,2.795e-03 meter / year
#  310, 1.000e+00 kiloyear,3.100e+02 kiloyear,2.787e-03 meter / year
#  311, 1.000e+00 kiloyear,3.110e+02 kiloyear,3.064e-03 meter / year
#  312, 1.000e+00 kiloyear,3.120e+02 kiloyear,2.832e-03 meter / year
#  313, 1.000e+00 kiloyear,3.130e+02 kiloyear,3.050e-03 meter / year
#  314, 1.000e+00 kiloyear,3.140e+02 kiloyear,3.067e-03 meter / year
#  315, 1.000e+00 kiloyear,3.150e+02 kiloyear,2.871e-03 meter / year
#  316, 1.000e+00 kiloyear,3.160e+02 kiloyear,2.847e-03 meter / year
#  317, 1.000e+00 kiloyear,3.170e+02 kiloyear,2.757e-03 meter / year
#  318, 1.000e+00 kiloyear,3.180e+02 kiloyear,2.742e-03 meter / year
#  319, 1.000e+00 kiloyear,3.190e+02 kiloyear,2.787e-03 meter / year
#  320, 1.000e+00 kiloyear,3.200e+02 kiloyear,2.856e-03 meter / year
#  321, 1.000e+00 kiloyear,3.210e+02 kiloyear,2.754e-03 meter / year
#  322, 1.000e+00 kiloyear,3.220e+02 kiloyear,2.920e-03 meter / year
#  323, 1.000e+00 kiloyear,3.230e+02 kiloyear,2.762e-03 meter / year
#  324, 1.000e+00 kiloyear,3.240e+02 kiloyear,2.995e-03 meter / year
#  325, 1.000e+00 kiloyear,3.250e+02 kiloyear,2.937e-03 meter / year
#  326, 1.000e+00 kiloyear,3.260e+02 kiloyear,2.798e-03 meter / year
#  327, 1.000e+00 kiloyear,3.270e+02 kiloyear,2.733e-03 meter / year
#  328, 1.000e+00 kiloyear,3.280e+02 kiloyear,2.805e-03 meter / year
#  329, 1.000e+00 kiloyear,3.290e+02 kiloyear,2.793e-03 meter / year
#  330, 1.000e+00 kiloyear,3.300e+02 kiloyear,2.815e-03 meter / year
#  331, 1.000e+00 kiloyear,3.310e+02 kiloyear,2.801e-03 meter / year
#  332, 1.000e+00 kiloyear,3.320e+02 kiloyear,2.830e-03 meter / year
#  333, 1.000e+00 kiloyear,3.330e+02 kiloyear,2.847e-03 meter / year
#  334, 1.000e+00 kiloyear,3.340e+02 kiloyear,2.781e-03 meter / year
#  335, 1.000e+00 kiloyear,3.350e+02 kiloyear,2.878e-03 meter / year
#  336, 1.000e+00 kiloyear,3.360e+02 kiloyear,2.851e-03 meter / year
#  337, 1.000e+00 kiloyear,3.370e+02 kiloyear,2.850e-03 meter / year
#  338, 1.000e+00 kiloyear,3.380e+02 kiloyear,2.794e-03 meter / year
#  339, 1.000e+00 kiloyear,3.390e+02 kiloyear,2.788e-03 meter / year
#  340, 1.000e+00 kiloyear,3.400e+02 kiloyear,3.054e-03 meter / year
#  341, 1.000e+00 kiloyear,3.410e+02 kiloyear,2.995e-03 meter / year
#  342, 1.000e+00 kiloyear,3.420e+02 kiloyear,3.023e-03 meter / year
#  343, 1.000e+00 kiloyear,3.430e+02 kiloyear,3.087e-03 meter / year
#  344, 1.000e+00 kiloyear,3.440e+02 kiloyear,3.027e-03 meter / year
#  345, 1.000e+00 kiloyear,3.450e+02 kiloyear,2.985e-03 meter / year
#  346, 1.000e+00 kiloyear,3.460e+02 kiloyear,2.957e-03 meter / year
#  347, 1.000e+00 kiloyear,3.470e+02 kiloyear,2.904e-03 meter / year
#  348, 1.000e+00 kiloyear,3.480e+02 kiloyear,3.036e-03 meter / year
#  349, 1.000e+00 kiloyear,3.490e+02 kiloyear,2.947e-03 meter / year
#  350, 1.000e+00 kiloyear,3.500e+02 kiloyear,3.053e-03 meter / year
#  351, 1.000e+00 kiloyear,3.510e+02 kiloyear,2.949e-03 meter / year
#  352, 1.000e+00 kiloyear,3.520e+02 kiloyear,2.807e-03 meter / year
#  353, 1.000e+00 kiloyear,3.530e+02 kiloyear,2.812e-03 meter / year
#  354, 1.000e+00 kiloyear,3.540e+02 kiloyear,2.845e-03 meter / year
#  355, 1.000e+00 kiloyear,3.550e+02 kiloyear,2.849e-03 meter / year
#  356, 1.000e+00 kiloyear,3.560e+02 kiloyear,2.921e-03 meter / year
#  357, 1.000e+00 kiloyear,3.570e+02 kiloyear,2.983e-03 meter / year
#  358, 1.000e+00 kiloyear,3.580e+02 kiloyear,2.857e-03 meter / year
#  359, 1.000e+00 kiloyear,3.590e+02 kiloyear,2.898e-03 meter / year
#  360, 1.000e+00 kiloyear,3.600e+02 kiloyear,3.112e-03 meter / year
#  361, 1.000e+00 kiloyear,3.610e+02 kiloyear,3.150e-03 meter / year
#  362, 1.000e+00 kiloyear,3.620e+02 kiloyear,3.074e-03 meter / year
#  363, 1.000e+00 kiloyear,3.630e+02 kiloyear,2.981e-03 meter / year
#  364, 1.000e+00 kiloyear,3.640e+02 kiloyear,3.051e-03 meter / year
#  365, 1.000e+00 kiloyear,3.650e+02 kiloyear,3.260e-03 meter / year
#  366, 1.000e+00 kiloyear,3.660e+02 kiloyear,3.045e-03 meter / year
#  367, 1.000e+00 kiloyear,3.670e+02 kiloyear,3.001e-03 meter / year
#  368, 1.000e+00 kiloyear,3.680e+02 kiloyear,3.097e-03 meter / year
#  369, 1.000e+00 kiloyear,3.690e+02 kiloyear,3.105e-03 meter / year
#  370, 1.000e+00 kiloyear,3.700e+02 kiloyear,3.035e-03 meter / year
#  371, 1.000e+00 kiloyear,3.710e+02 kiloyear,3.010e-03 meter / year
#  372, 1.000e+00 kiloyear,3.720e+02 kiloyear,3.030e-03 meter / year
#  373, 1.000e+00 kiloyear,3.730e+02 kiloyear,3.025e-03 meter / year
#  374, 1.000e+00 kiloyear,3.740e+02 kiloyear,3.101e-03 meter / year
#  375, 1.000e+00 kiloyear,3.750e+02 kiloyear,3.033e-03 meter / year
#  376, 1.000e+00 kiloyear,3.760e+02 kiloyear,3.037e-03 meter / year
#  377, 1.000e+00 kiloyear,3.770e+02 kiloyear,3.124e-03 meter / year
#  378, 1.000e+00 kiloyear,3.780e+02 kiloyear,3.118e-03 meter / year
#  379, 1.000e+00 kiloyear,3.790e+02 kiloyear,3.060e-03 meter / year
#  380, 1.000e+00 kiloyear,3.800e+02 kiloyear,3.086e-03 meter / year
#  381, 1.000e+00 kiloyear,3.810e+02 kiloyear,3.166e-03 meter / year
#  382, 1.000e+00 kiloyear,3.820e+02 kiloyear,3.196e-03 meter / year
#  383, 1.000e+00 kiloyear,3.830e+02 kiloyear,3.153e-03 meter / year
#  384, 1.000e+00 kiloyear,3.840e+02 kiloyear,2.984e-03 meter / year
#  385, 1.000e+00 kiloyear,3.850e+02 kiloyear,2.949e-03 meter / year
#  386, 1.000e+00 kiloyear,3.860e+02 kiloyear,2.973e-03 meter / year
#  387, 1.000e+00 kiloyear,3.870e+02 kiloyear,3.387e-03 meter / year
#  388, 1.000e+00 kiloyear,3.880e+02 kiloyear,3.261e-03 meter / year
#  389, 1.000e+00 kiloyear,3.890e+02 kiloyear,3.153e-03 meter / year
#  390, 1.000e+00 kiloyear,3.900e+02 kiloyear,3.106e-03 meter / year
#  391, 1.000e+00 kiloyear,3.910e+02 kiloyear,3.148e-03 meter / year
#  392, 1.000e+00 kiloyear,3.920e+02 kiloyear,3.188e-03 meter / year
#  393, 1.000e+00 kiloyear,3.930e+02 kiloyear,3.148e-03 meter / year
#  394, 1.000e+00 kiloyear,3.940e+02 kiloyear,3.012e-03 meter / year
#  395, 1.000e+00 kiloyear,3.950e+02 kiloyear,3.142e-03 meter / year
#  396, 1.000e+00 kiloyear,3.960e+02 kiloyear,3.119e-03 meter / year
#  397, 1.000e+00 kiloyear,3.970e+02 kiloyear,3.195e-03 meter / year
#  398, 1.000e+00 kiloyear,3.980e+02 kiloyear,3.160e-03 meter / year
#  399, 1.000e+00 kiloyear,3.990e+02 kiloyear,3.117e-03 meter / year
#  400, 1.000e+00 kiloyear,4.000e+02 kiloyear,3.296e-03 meter / year
#  401, 1.000e+00 kiloyear,4.010e+02 kiloyear,3.166e-03 meter / year
#  402, 1.000e+00 kiloyear,4.020e+02 kiloyear,3.233e-03 meter / year
#  403, 1.000e+00 kiloyear,4.030e+02 kiloyear,3.110e-03 meter / year
#  404, 1.000e+00 kiloyear,4.040e+02 kiloyear,3.134e-03 meter / year
#  405, 1.000e+00 kiloyear,4.050e+02 kiloyear,3.080e-03 meter / year
#  406, 1.000e+00 kiloyear,4.060e+02 kiloyear,3.120e-03 meter / year
#  407, 1.000e+00 kiloyear,4.070e+02 kiloyear,3.122e-03 meter / year
#  408, 1.000e+00 kiloyear,4.080e+02 kiloyear,3.215e-03 meter / year
#  409, 1.000e+00 kiloyear,4.090e+02 kiloyear,3.219e-03 meter / year
#  410, 1.000e+00 kiloyear,4.100e+02 kiloyear,3.272e-03 meter / year
#  411, 1.000e+00 kiloyear,4.110e+02 kiloyear,3.242e-03 meter / year
#  412, 1.000e+00 kiloyear,4.120e+02 kiloyear,3.258e-03 meter / year
#  413, 1.000e+00 kiloyear,4.130e+02 kiloyear,3.213e-03 meter / year
#  414, 1.000e+00 kiloyear,4.140e+02 kiloyear,3.199e-03 meter / year
#  415, 1.000e+00 kiloyear,4.150e+02 kiloyear,3.192e-03 meter / year
#  416, 1.000e+00 kiloyear,4.160e+02 kiloyear,3.157e-03 meter / year
#  417, 1.000e+00 kiloyear,4.170e+02 kiloyear,3.378e-03 meter / year
#  418, 1.000e+00 kiloyear,4.180e+02 kiloyear,3.183e-03 meter / year
#  419, 1.000e+00 kiloyear,4.190e+02 kiloyear,3.207e-03 meter / year
#  420, 1.000e+00 kiloyear,4.200e+02 kiloyear,3.394e-03 meter / year
#  421, 1.000e+00 kiloyear,4.210e+02 kiloyear,3.478e-03 meter / year
#  422, 1.000e+00 kiloyear,4.220e+02 kiloyear,3.392e-03 meter / year
#  423, 1.000e+00 kiloyear,4.230e+02 kiloyear,3.306e-03 meter / year
#  424, 1.000e+00 kiloyear,4.240e+02 kiloyear,3.187e-03 meter / year
#  425, 1.000e+00 kiloyear,4.250e+02 kiloyear,3.267e-03 meter / year
#  426, 1.000e+00 kiloyear,4.260e+02 kiloyear,3.446e-03 meter / year
#  427, 1.000e+00 kiloyear,4.270e+02 kiloyear,3.198e-03 meter / year
#  428, 1.000e+00 kiloyear,4.280e+02 kiloyear,3.152e-03 meter / year
#  429, 1.000e+00 kiloyear,4.290e+02 kiloyear,3.137e-03 meter / year
#  430, 1.000e+00 kiloyear,4.300e+02 kiloyear,3.200e-03 meter / year
#  431, 1.000e+00 kiloyear,4.310e+02 kiloyear,3.261e-03 meter / year
#  432, 1.000e+00 kiloyear,4.320e+02 kiloyear,3.209e-03 meter / year
#  433, 1.000e+00 kiloyear,4.330e+02 kiloyear,3.673e-03 meter / year
#  434, 1.000e+00 kiloyear,4.340e+02 kiloyear,3.501e-03 meter / year
#  435, 1.000e+00 kiloyear,4.350e+02 kiloyear,3.381e-03 meter / year
#  436, 1.000e+00 kiloyear,4.360e+02 kiloyear,3.518e-03 meter / year
#  437, 1.000e+00 kiloyear,4.370e+02 kiloyear,3.262e-03 meter / year
#  438, 1.000e+00 kiloyear,4.380e+02 kiloyear,3.358e-03 meter / year
#  439, 1.000e+00 kiloyear,4.390e+02 kiloyear,3.423e-03 meter / year
#  440, 1.000e+00 kiloyear,4.400e+02 kiloyear,3.247e-03 meter / year
#  441, 1.000e+00 kiloyear,4.410e+02 kiloyear,3.255e-03 meter / year
#  442, 1.000e+00 kiloyear,4.420e+02 kiloyear,3.353e-03 meter / year
#  443, 1.000e+00 kiloyear,4.430e+02 kiloyear,3.374e-03 meter / year
#  444, 1.000e+00 kiloyear,4.440e+02 kiloyear,3.344e-03 meter / year
#  445, 1.000e+00 kiloyear,4.450e+02 kiloyear,3.327e-03 meter / year
#  446, 1.000e+00 kiloyear,4.460e+02 kiloyear,3.592e-03 meter / year
#  447, 1.000e+00 kiloyear,4.470e+02 kiloyear,3.518e-03 meter / year
#  448, 1.000e+00 kiloyear,4.480e+02 kiloyear,3.321e-03 meter / year
#  449, 1.000e+00 kiloyear,4.490e+02 kiloyear,3.663e-03 meter / year
#  450, 1.000e+00 kiloyear,4.500e+02 kiloyear,3.528e-03 meter / year
#  451, 1.000e+00 kiloyear,4.510e+02 kiloyear,3.422e-03 meter / year
#  452, 1.000e+00 kiloyear,4.520e+02 kiloyear,3.557e-03 meter / year
#  453, 1.000e+00 kiloyear,4.530e+02 kiloyear,3.466e-03 meter / year
#  454, 1.000e+00 kiloyear,4.540e+02 kiloyear,3.255e-03 meter / year
#  455, 1.000e+00 kiloyear,4.550e+02 kiloyear,3.264e-03 meter / year
#  456, 1.000e+00 kiloyear,4.560e+02 kiloyear,3.320e-03 meter / year
#  457, 1.000e+00 kiloyear,4.570e+02 kiloyear,3.547e-03 meter / year
#  458, 1.000e+00 kiloyear,4.580e+02 kiloyear,3.473e-03 meter / year
#  459, 1.000e+00 kiloyear,4.590e+02 kiloyear,3.455e-03 meter / year
#  460, 1.000e+00 kiloyear,4.600e+02 kiloyear,3.447e-03 meter / year
#  461, 1.000e+00 kiloyear,4.610e+02 kiloyear,3.422e-03 meter / year
#  462, 1.000e+00 kiloyear,4.620e+02 kiloyear,3.406e-03 meter / year
#  463, 1.000e+00 kiloyear,4.630e+02 kiloyear,3.400e-03 meter / year
#  464, 1.000e+00 kiloyear,4.640e+02 kiloyear,3.482e-03 meter / year
#  465, 1.000e+00 kiloyear,4.650e+02 kiloyear,3.484e-03 meter / year
#  466, 1.000e+00 kiloyear,4.660e+02 kiloyear,3.481e-03 meter / year
#  467, 1.000e+00 kiloyear,4.670e+02 kiloyear,3.291e-03 meter / year
#  468, 1.000e+00 kiloyear,4.680e+02 kiloyear,3.333e-03 meter / year
#  469, 1.000e+00 kiloyear,4.690e+02 kiloyear,3.334e-03 meter / year
#  470, 1.000e+00 kiloyear,4.700e+02 kiloyear,3.653e-03 meter / year
#  471, 1.000e+00 kiloyear,4.710e+02 kiloyear,3.661e-03 meter / year
#  472, 1.000e+00 kiloyear,4.720e+02 kiloyear,3.620e-03 meter / year
#  473, 1.000e+00 kiloyear,4.730e+02 kiloyear,3.580e-03 meter / year
#  474, 1.000e+00 kiloyear,4.740e+02 kiloyear,3.562e-03 meter / year
#  475, 1.000e+00 kiloyear,4.750e+02 kiloyear,3.556e-03 meter / year
#  476, 1.000e+00 kiloyear,4.760e+02 kiloyear,3.535e-03 meter / year
#  477, 1.000e+00 kiloyear,4.770e+02 kiloyear,3.543e-03 meter / year
#  478, 1.000e+00 kiloyear,4.780e+02 kiloyear,3.499e-03 meter / year
#  479, 1.000e+00 kiloyear,4.790e+02 kiloyear,3.337e-03 meter / year
#  480, 1.000e+00 kiloyear,4.800e+02 kiloyear,3.354e-03 meter / year
#  481, 1.000e+00 kiloyear,4.810e+02 kiloyear,3.369e-03 meter / year
#  482, 1.000e+00 kiloyear,4.820e+02 kiloyear,3.396e-03 meter / year
#  483, 1.000e+00 kiloyear,4.830e+02 kiloyear,3.397e-03 meter / year
#  484, 1.000e+00 kiloyear,4.840e+02 kiloyear,3.369e-03 meter / year
#  485, 1.000e+00 kiloyear,4.850e+02 kiloyear,3.556e-03 meter / year
#  486, 1.000e+00 kiloyear,4.860e+02 kiloyear,3.363e-03 meter / year
#  487, 1.000e+00 kiloyear,4.870e+02 kiloyear,3.452e-03 meter / year
#  488, 1.000e+00 kiloyear,4.880e+02 kiloyear,3.389e-03 meter / year
#  489, 1.000e+00 kiloyear,4.890e+02 kiloyear,3.510e-03 meter / year
#  490, 1.000e+00 kiloyear,4.900e+02 kiloyear,3.690e-03 meter / year
#  491, 1.000e+00 kiloyear,4.910e+02 kiloyear,3.644e-03 meter / year
#  492, 1.000e+00 kiloyear,4.920e+02 kiloyear,3.511e-03 meter / year
#  493, 1.000e+00 kiloyear,4.930e+02 kiloyear,3.657e-03 meter / year
#  494, 1.000e+00 kiloyear,4.940e+02 kiloyear,3.666e-03 meter / year
#  495, 1.000e+00 kiloyear,4.950e+02 kiloyear,3.882e-03 meter / year
#  496, 1.000e+00 kiloyear,4.960e+02 kiloyear,3.602e-03 meter / year
#  497, 1.000e+00 kiloyear,4.970e+02 kiloyear,3.877e-03 meter / year
#  498, 1.000e+00 kiloyear,4.980e+02 kiloyear,3.618e-03 meter / year
#  499, 1.000e+00 kiloyear,4.990e+02 kiloyear,3.696e-03 meter / year
#  500, 1.000e+00 kiloyear,5.000e+02 kiloyear,3.634e-03 meter / year
#  501, 1.000e+00 kiloyear,5.010e+02 kiloyear,3.598e-03 meter / year

# %%
fig3 = vis.Figure() #title="Material", figsize=(400,400), quality=2, rulers=True)
#fig1.Points(swarm, materialIndex, fn_size=2.,discret=True,colourBar = False) 
#fig1.VectorArrows(mesh, velocityField) 
fig3.Mesh(mesh) 
fig3.show()
fig3.save_image(output_path+"mesh_steptest")
# Out:
# <img src='data:image/png;base64,...'>
# 'Kaus2010RTI_FreeSurface_1.0ka_test_novo/mesh_steptest.png'

# %%
import matplotlib.pyplot as plt

# %%
top = mesh.specialSets["Top_VertexSet"]
top
topx = mesh.data[top.data,0]
topy = mesh.data[top.data,1]
len_scale = 500

# %%
fig, ax1 = plt.subplots(nrows=1, figsize=(10,5))
ax1.set(xlabel='element index', ylabel='displacement [km]') #,xticks=xticks_fig,yticks=yticks_fig,title=fname_fig)
ax1.plot(topy*len_scale,label='all')
ax1.plot(topy[0:32]*len_scale,label='left')
ax1.plot(topy[33:][::-1]*len_scale,label = 'right')
ax1.legend(loc = 'upper left',prop = {'size':12})

# %%
x =  mesh.data[top.data][:, 0]
y =  mesh.data[top.data][:, 1]

# Extract velocities from top
vx = velocityField.data[top.data][:, 0]
vy = velocityField.data[top.data][:, 1]

# Advect top surface
x2 = x + vx * nd(dt)
y2 = y + vy * nd(dt)

# Spline top surface
f = interp1d(x2, y2, kind='cubic', fill_value='extrapolate')

tem = f(x)

# %%
fig, ax1 = plt.subplots(nrows=1, figsize=(10,5))
ax1.set(xlabel='element index', ylabel='displacement [km]') #,xticks=xticks_fig,yticks=yticks_fig,title=fname_fig)
ax1.plot(vx * nd(dt)*len_scale,label='all')
ax1.legend(loc = 'upper left',prop = {'size':12})

# %%
fig, ax1 = plt.subplots(nrows=1, figsize=(10,5))
ax1.set(xlabel='element index', ylabel='displacement [km]') #,xticks=xticks_fig,yticks=yticks_fig,title=fname_fig)
ax1.plot(vy * nd(dt)*len_scale,label='all')
ax1.legend(loc = 'upper left',prop = {'size':12})
